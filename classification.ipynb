# %%
# %pip install earthengine-api geemap
# Out:
# Collecting earthengine-api
#   Using cached earthengine_api-1.5.14-py3-none-any.whl.metadata (2.1 kB)
# Collecting geemap
#   Using cached geemap-0.35.3-py2.py3-none-any.whl.metadata (12 kB)
# Collecting google-cloud-storage (from earthengine-api)
#   Using cached google_cloud_storage-3.1.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting google-api-python-client>=1.12.1 (from earthengine-api)
#   Using cached google_api_python_client-2.169.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=1.4.1 (from earthengine-api)
#   Using cached google_auth-2.40.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-httplib2>=0.0.3 (from earthengine-api)
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting httplib2<1dev,>=0.9.2 (from earthengine-api)
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting requests (from earthengine-api)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<1dev,>=0.9.2->earthengine-api)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting bqplot (from geemap)
#   Using cached bqplot-0.12.44-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting colour (from geemap)
#   Using cached colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Collecting eerepr>=0.1.0 (from geemap)
#   Using cached eerepr-0.1.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting folium>=0.17.0 (from geemap)
#   Using cached folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting geocoder (from geemap)
#   Using cached geocoder-1.38.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting ipyevents (from geemap)
#   Using cached ipyevents-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting ipyfilechooser>=0.6.0 (from geemap)
#   Using cached ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyleaflet>=0.19.2 (from geemap)
#   Using cached ipyleaflet-0.19.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting ipytree (from geemap)
#   Using cached ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting matplotlib (from geemap)
#   Using cached matplotlib-3.10.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (11 kB)
# Collecting numpy (from geemap)
#   Using cached numpy-2.2.5-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting pandas (from geemap)
#   Using cached pandas-2.2.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata (89 kB)
# Collecting plotly (from geemap)
#   Using cached plotly-6.0.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting pyperclip (from geemap)
#   Using cached pyperclip-1.9.0-py3-none-any.whl
# Collecting pyshp>=2.3.1 (from geemap)
#   Using cached pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# Collecting python-box (from geemap)
#   Using cached python_box-7.3.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (8.0 kB)
# Collecting scooby (from geemap)
#   Using cached scooby-0.10.1-py3-none-any.whl.metadata (15 kB)
# Collecting branca>=0.6.0 (from folium>=0.17.0->geemap)
#   Using cached branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting jinja2>=2.9 (from folium>=0.17.0->geemap)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting xyzservices (from folium>=0.17.0->geemap)
#   Using cached xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client>=1.12.1->earthengine-api)
#   Using cached google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.12.1->earthengine-api)
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api)
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api)
#   Using cached protobuf-6.30.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.4.1->earthengine-api)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.4.1->earthengine-api)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.4.1->earthengine-api)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->earthengine-api)
#   Using cached charset_normalizer-3.4.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->earthengine-api)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->earthengine-api)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->earthengine-api)
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=1.4.1->earthengine-api)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting ipywidgets (from ipyfilechooser>=0.6.0->geemap)
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting jupyter-leaflet<0.20,>=0.19 (from ipyleaflet>=0.19.2->geemap)
#   Using cached jupyter_leaflet-0.19.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting traittypes<3,>=0.2.1 (from ipyleaflet>=0.19.2->geemap)
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting comm>=0.1.3 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting ipython>=6.1.0 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached ipython-9.2.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting traitlets>=4.3.1 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting decorator (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting pexpect>4.3 (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached prompt_toolkit-3.0.51-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium>=0.17.0->geemap)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.0 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->geemap)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->geemap)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->geemap)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas->geemap)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting click (from geocoder->geemap)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting future (from geocoder->geemap)
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting ratelim (from geocoder->geemap)
#   Using cached ratelim-0.1.6-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client>=1.12.1->earthengine-api)
#   Using cached google_api_core-2.25.0rc1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-cloud-core<3.0dev,>=2.4.2 (from google-cloud-storage->earthengine-api)
#   Using cached google_cloud_core-2.4.3-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.7.2 (from google-cloud-storage->earthengine-api)
#   Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage->earthengine-api)
#   Using cached google_crc32c-1.7.1-cp312-cp312-macosx_12_0_x86_64.whl.metadata (2.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->geemap)
#   Using cached contourpy-1.3.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->geemap)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->geemap)
#   Using cached fonttools-4.57.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->geemap)
#   Using cached kiwisolver-1.4.8-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.2 kB)
# Collecting packaging>=20.0 (from matplotlib->geemap)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow>=8 (from matplotlib->geemap)
#   Using cached pillow-11.2.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (8.9 kB)
# Collecting narwhals>=1.15.1 (from plotly->geemap)
#   Using cached narwhals-1.38.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Using cached earthengine_api-1.5.14-py3-none-any.whl (462 kB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached geemap-0.35.3-py2.py3-none-any.whl (2.3 MB)
# Using cached eerepr-0.1.2-py3-none-any.whl (9.5 kB)
# Using cached folium-0.19.5-py2.py3-none-any.whl (110 kB)
# Using cached branca-0.8.1-py3-none-any.whl (26 kB)
# Using cached google_api_python_client-2.169.0-py3-none-any.whl (13.3 MB)
# Using cached google_api_core-2.24.2-py3-none-any.whl (160 kB)
# Using cached google_auth-2.40.1-py2.py3-none-any.whl (216 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached protobuf-6.30.2-cp39-abi3-macosx_10_9_universal2.whl (417 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp312-cp312-macosx_10_13_universal2.whl (199 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Using cached ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Using cached ipyleaflet-0.19.2-py3-none-any.whl (31 kB)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyter_leaflet-0.19.2-py3-none-any.whl (1.1 MB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Using cached ipython-9.2.0-py3-none-any.whl (604 kB)
# Using cached prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-macosx_10_13_universal2.whl (14 kB)
# Using cached pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pygments-2.19.1-py3-none-any.whl (1.2 MB)
# Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Using cached bqplot-0.12.44-py2.py3-none-any.whl (1.2 MB)
# Using cached pandas-2.2.3-cp312-cp312-macosx_10_9_x86_64.whl (12.5 MB)
# Using cached numpy-2.2.5-cp312-cp312-macosx_14_0_x86_64.whl (6.7 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Using cached geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached google_cloud_storage-3.1.0-py2.py3-none-any.whl (174 kB)
# Using cached google_cloud_core-2.4.3-py2.py3-none-any.whl (29 kB)
# Using cached google_crc32c-1.7.1-cp312-cp312-macosx_12_0_x86_64.whl (30 kB)
# Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Using cached ipyevents-2.0.2-py3-none-any.whl (101 kB)
# Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Using cached ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
# Using cached matplotlib-3.10.3-cp312-cp312-macosx_10_13_x86_64.whl (8.2 MB)
# Using cached contourpy-1.3.2-cp312-cp312-macosx_10_13_x86_64.whl (271 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.57.0-cp312-cp312-macosx_10_13_x86_64.whl (2.3 MB)
# Using cached kiwisolver-1.4.8-cp312-cp312-macosx_10_13_x86_64.whl (66 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pillow-11.2.1-cp312-cp312-macosx_10_13_x86_64.whl (3.2 MB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached plotly-6.0.1-py3-none-any.whl (14.8 MB)
# Using cached narwhals-1.38.2-py3-none-any.whl (338 kB)
# Using cached python_box-7.3.2-cp312-cp312-macosx_10_13_universal2.whl (1.8 MB)
# Using cached ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Using cached scooby-0.10.1-py3-none-any.whl (18 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Using cached executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, pytz, pyperclip, pure-eval, ptyprocess, colour, xyzservices, widgetsnbextension, urllib3, uritemplate, tzdata, traitlets, six, scooby, python-box, pyshp, pyparsing, pygments, pyasn1, protobuf, prompt_toolkit, pillow, pexpect, parso, packaging, numpy, narwhals, MarkupSafe, kiwisolver, jupyterlab_widgets, jupyter-leaflet, idna, google-crc32c, future, fonttools, executing, decorator, cycler, click, charset-normalizer, certifi, cachetools, asttokens, traittypes, stack_data, rsa, requests, ratelim, python-dateutil, pyasn1-modules, proto-plus, plotly, matplotlib-inline, jinja2, jedi, ipython-pygments-lexers, httplib2, googleapis-common-protos, google-resumable-media, contourpy, comm, pandas, matplotlib, ipython, google-auth, geocoder, branca, ipywidgets, google-auth-httplib2, google-api-core, folium, ipytree, ipyleaflet, ipyfilechooser, ipyevents, google-cloud-core, google-api-python-client, bqplot, google-cloud-storage, earthengine-api, eerepr, geemap
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82/82 [geemap] [geemap] [earthengine-api]n-client]
# Successfully installed MarkupSafe-3.0.2 asttokens-3.0.0 bqplot-0.12.44 branca-0.8.1 cachetools-5.5.2 certifi-2025.4.26 charset-normalizer-3.4.2 click-8.1.8 colour-0.1.5 comm-0.2.2 contourpy-1.3.2 cycler-0.12.1 decorator-5.2.1 earthengine-api-1.5.14 eerepr-0.1.2 executing-2.2.0 folium-0.19.5 fonttools-4.57.0 future-1.0.0 geemap-0.35.3 geocoder-1.38.1 google-api-core-2.24.2 google-api-python-client-2.169.0 google-auth-2.40.1 google-auth-httplib2-0.2.0 google-cloud-core-2.4.3 google-cloud-storage-3.1.0 google-crc32c-1.7.1 google-resumable-media-2.7.2 googleapis-common-protos-1.70.0 httplib2-0.22.0 idna-3.10 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.19.2 ipython-9.2.0 ipython-pygments-lexers-1.1.1 ipytree-0.2.2 ipywidgets-8.1.7 jedi-0.19.2 jinja2-3.1.6 jupyter-leaflet-0.19.2 jupyterlab_widgets-3.0.15 kiwisolver-1.4.8 matplotlib-3.10.3 matplotlib-inline-0.1.7 narwhals-1.38.2 numpy-2.2.5 packaging-25.0 pandas-2.2.3 parso-0.8.4 pexpect-4.9.0 pillow-11.2.1 plotly-6.0.1 prompt_toolkit-3.0.51 proto-plus-1.26.1 protobuf-6.30.2 ptyprocess-0.7.0 pure-eval-0.2.3 pyasn1-0.6.1 pyasn1-modules-0.4.2 pygments-2.19.1 pyparsing-3.2.3 pyperclip-1.9.0 pyshp-2.3.1 python-box-7.3.2 python-dateutil-2.9.0.post0 pytz-2025.2 ratelim-0.1.6 requests-2.32.3 rsa-4.9.1 scooby-0.10.1 six-1.17.0 stack_data-0.6.3 traitlets-5.14.3 traittypes-0.2.1 tzdata-2025.2 uritemplate-4.1.1 urllib3-2.4.0 wcwidth-0.2.13 widgetsnbextension-4.0.14 xyzservices-2025.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall earthengine-api geemap

# %%
# %pip install earthengine-api geemap setuptools
import ee
import geemap

ee.Authenticate()  # Only needed once
ee.Initialize(project='classification-459108')

# Create interactive map
Map = geemap.Map(center=[17.7009, 83.277], zoom=12)

# Sentinel-2 SR collection with cloud filtering
collection = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
    .filterDate('2020-01-01', '2020-01-30') \
    .filterBounds(ee.Geometry.Point(83.277, 17.7009)) \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))

# Cloud masking
def maskS2clouds(image):
    qa = image.select('QA60')
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(qa.bitwiseAnd(cirrusBitMask).eq(0))
    return image.updateMask(mask).divide(10000)

composite = collection.map(maskS2clouds).median()

# Select relevant bands
bands = ['B2', 'B3', 'B4', 'B8']

# Sample training data (manually define a few polygons for classes)
# Replace these with your actual geometries and labels
water = ee.FeatureCollection([
    ee.Feature(ee.Geometry.Point(83.274, 17.698), {'landcover': 0}),
    ee.Feature(ee.Geometry.Point(83.273, 17.699), {'landcover': 0}),
])

vegetation = ee.FeatureCollection([
    ee.Feature(ee.Geometry.Point(83.275, 17.702), {'landcover': 1}),
    ee.Feature(ee.Geometry.Point(83.276, 17.703), {'landcover': 1}),
])

urban = ee.FeatureCollection([
    ee.Feature(ee.Geometry.Point(83.278, 17.701), {'landcover': 2}),
    ee.Feature(ee.Geometry.Point(83.279, 17.700), {'landcover': 2}),
])

# Merge all classes
training_data = water.merge(vegetation).merge(urban)

# Sample the composite image using training points
training = composite.select(bands).sampleRegions(
    collection=training_data,
    properties=['landcover'],
    scale=10
)

# Train a classifier
# Train the classifier
classifier = ee.Classifier.smileRandomForest(100).train(
    features=training,
    classProperty='landcover',
    inputProperties=bands
)

# Classify the same training samples for evaluation
classified_training = training.classify(classifier)

# Generate confusion matrix
conf_matrix = classified_training.errorMatrix('landcover', 'classification')
print('Confusion Matrix (on training data):')
print(conf_matrix.getInfo())
print('Accuracy:', conf_matrix.accuracy().getInfo())

# Classify the image
classified = composite.select(bands).classify(classifier)

# Visualization parameters for classified map
class_vis = {
    'min': 0,
    'max': 2,
    'palette': ['0000FF', '00FF00', 'FF0000']  # water, vegetation, urban
}

# Add layers to map
Map.addLayer(composite, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 0.3}, 'RGB Composite')
Map.addLayer(classified, class_vis, 'Land Cover Classification')
Map.addLayerControl()
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: earthengine-api in ./.venv/lib/python3.12/site-packages (1.5.14)
# Requirement already satisfied: geemap in ./.venv/lib/python3.12/site-packages (0.35.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (80.3.1)
# Requirement already satisfied: google-cloud-storage in ./.venv/lib/python3.12/site-packages (from earthengine-api) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in ./.venv/lib/python3.12/site-packages (from earthengine-api) (2.169.0)
# Requirement already satisfied: google-auth>=1.4.1 in ./.venv/lib/python3.12/site-packages (from earthengine-api) (2.40.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in ./.venv/lib/python3.12/site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in ./.venv/lib/python3.12/site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in ./.venv/lib/python3.12/site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.3)
# Requirement already satisfied: bqplot in ./.venv/lib/python3.12/site-packages (from geemap) (0.12.44)
# Requirement already satisfied: colour in ./.venv/lib/python3.12/site-packages (from geemap) (0.1.5)
# Requirement already satisfied: eerepr>=0.1.0 in ./.venv/lib/python3.12/site-packages (from geemap) (0.1.2)
# Requirement already satisfied: folium>=0.17.0 in ./.venv/lib/python3.12/site-packages (from geemap) (0.19.5)
# Requirement already satisfied: geocoder in ./.venv/lib/python3.12/site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in ./.venv/lib/python3.12/site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in ./.venv/lib/python3.12/site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in ./.venv/lib/python3.12/site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in ./.venv/lib/python3.12/site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (from geemap) (3.10.3)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from geemap) (2.2.5)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from geemap) (2.2.3)
# Requirement already satisfied: plotly in ./.venv/lib/python3.12/site-packages (from geemap) (6.0.1)
# Requirement already satisfied: pyperclip in ./.venv/lib/python3.12/site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in ./.venv/lib/python3.12/site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in ./.venv/lib/python3.12/site-packages (from geemap) (7.3.2)
# Requirement already satisfied: scooby in ./.venv/lib/python3.12/site-packages (from geemap) (0.10.1)
# Requirement already satisfied: branca>=0.6.0 in ./.venv/lib/python3.12/site-packages (from folium>=0.17.0->geemap) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in ./.venv/lib/python3.12/site-packages (from folium>=0.17.0->geemap) (3.1.6)
# Requirement already satisfied: xyzservices in ./.venv/lib/python3.12/site-packages (from folium>=0.17.0->geemap) (2025.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in ./.venv/lib/python3.12/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in ./.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in ./.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (6.30.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in ./.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->earthengine-api) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->earthengine-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->earthengine-api) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->earthengine-api) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.12/site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.7)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in ./.venv/lib/python3.12/site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in ./.venv/lib/python3.12/site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (9.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.15)
# Requirement already satisfied: decorator in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.1)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->geemap) (1.17.0)
# Requirement already satisfied: click in ./.venv/lib/python3.12/site-packages (from geocoder->geemap) (8.1.8)
# Requirement already satisfied: future in ./.venv/lib/python3.12/site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in ./.venv/lib/python3.12/site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in ./.venv/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in ./.venv/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in ./.venv/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api) (1.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->geemap) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->geemap) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->geemap) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->geemap) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib->geemap) (11.2.1)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv/lib/python3.12/site-packages (from plotly->geemap) (1.38.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Confusion Matrix (on training data):
# [[2, 0, 0], [0, 2, 0], [0, 0, 2]]
# Accuracy: 1
# Map(center=[17.7009, 83.277], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDat…

# %%
# %pip install earthengine-api geemap opencv-python-headless numpy matplotlib
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: earthengine-api in ./.venv/lib/python3.12/site-packages (1.5.14)
# Requirement already satisfied: geemap in ./.venv/lib/python3.12/site-packages (0.35.3)
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.2.5)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: google-cloud-storage in ./.venv/lib/python3.12/site-packages (from earthengine-api) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in ./.venv/lib/python3.12/site-packages (from earthengine-api) (2.169.0)
# Requirement already satisfied: google-auth>=1.4.1 in ./.venv/lib/python3.12/site-packages (from earthengine-api) (2.40.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in ./.venv/lib/python3.12/site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in ./.venv/lib/python3.12/site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in ./.venv/lib/python3.12/site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.3)
# Requirement already satisfied: bqplot in ./.venv/lib/python3.12/site-packages (from geemap) (0.12.44)
# Requirement already satisfied: colour in ./.venv/lib/python3.12/site-packages (from geemap) (0.1.5)
# Requirement already satisfied: eerepr>=0.1.0 in ./.venv/lib/python3.12/site-packages (from geemap) (0.1.2)
# Requirement already satisfied: folium>=0.17.0 in ./.venv/lib/python3.12/site-packages (from geemap) (0.19.5)
# Requirement already satisfied: geocoder in ./.venv/lib/python3.12/site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in ./.venv/lib/python3.12/site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in ./.venv/lib/python3.12/site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in ./.venv/lib/python3.12/site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in ./.venv/lib/python3.12/site-packages (from geemap) (0.2.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from geemap) (2.2.3)
# Requirement already satisfied: plotly in ./.venv/lib/python3.12/site-packages (from geemap) (6.0.1)
# Requirement already satisfied: pyperclip in ./.venv/lib/python3.12/site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in ./.venv/lib/python3.12/site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in ./.venv/lib/python3.12/site-packages (from geemap) (7.3.2)
# Requirement already satisfied: scooby in ./.venv/lib/python3.12/site-packages (from geemap) (0.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: branca>=0.6.0 in ./.venv/lib/python3.12/site-packages (from folium>=0.17.0->geemap) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in ./.venv/lib/python3.12/site-packages (from folium>=0.17.0->geemap) (3.1.6)
# Requirement already satisfied: xyzservices in ./.venv/lib/python3.12/site-packages (from folium>=0.17.0->geemap) (2025.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in ./.venv/lib/python3.12/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in ./.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in ./.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (6.30.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in ./.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->earthengine-api) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->earthengine-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->earthengine-api) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->earthengine-api) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.12/site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.7)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in ./.venv/lib/python3.12/site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in ./.venv/lib/python3.12/site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (9.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./.venv/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.15)
# Requirement already satisfied: decorator in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.1)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: click in ./.venv/lib/python3.12/site-packages (from geocoder->geemap) (8.1.8)
# Requirement already satisfied: future in ./.venv/lib/python3.12/site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in ./.venv/lib/python3.12/site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in ./.venv/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in ./.venv/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in ./.venv/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api) (1.7.1)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv/lib/python3.12/site-packages (from plotly->geemap) (1.38.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_x86_64.whl (56.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 12.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.11.0.86
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee
import geemap
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import display

ee.Authenticate()  # Only needed once
ee.Initialize(project='classification-459108')

# Define Area of Interest (AOI)
aoi = ee.Geometry.Rectangle([83.26, 17.69, 83.29, 17.71])

# Create interactive map and center on AOI
Map = geemap.Map()
Map.centerObject(aoi, 12)

# Sentinel-2 SR collection with cloud filtering
collection = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
    .filterDate('2020-01-01', '2020-01-30') \
    .filterBounds(aoi) \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))

# Cloud masking
def maskS2clouds(image):
    qa = image.select('QA60')
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(qa.bitwiseAnd(cirrusBitMask).eq(0))
    return image.updateMask(mask).divide(10000)

composite = collection.map(maskS2clouds).median()

# Clip the image to our AOI
composite = composite.clip(aoi)

# Calculate NDVI and add it as a band
ndvi = composite.normalizedDifference(['B8', 'B4']).rename('NDVI')
composite = composite.addBands(ndvi)

# Select relevant bands including NDVI
bands = ['B2', 'B3', 'B4', 'B8', 'NDVI']

# Sample training data using polygons instead of points
water = ee.FeatureCollection([
    ee.Feature(ee.Geometry.Polygon([
        [[83.2735, 17.6975], [83.2735, 17.6985], [83.2745, 17.6985], [83.2745, 17.6975], [83.2735, 17.6975]]
    ]), {'landcover': 0}),
])

vegetation = ee.FeatureCollection([
    ee.Feature(ee.Geometry.Polygon([
        [[83.275, 17.702], [83.275, 17.703], [83.276, 17.703], [83.276, 17.702], [83.275, 17.702]]
    ]), {'landcover': 1}),
])

urban = ee.FeatureCollection([
    ee.Feature(ee.Geometry.Polygon([
        [[83.278, 17.700], [83.278, 17.701], [83.279, 17.701], [83.279, 17.700], [83.278, 17.700]]
    ]), {'landcover': 2}),
])

# Merge all classes
training_data = water.merge(vegetation).merge(urban)

# Sample the composite image using training polygons
training = composite.select(bands).sampleRegions(
    collection=training_data,
    properties=['landcover'],
    scale=10
)

# Add a random column for splitting data
training = training.randomColumn('random')

# Split into training (70%) and validation (30%) sets
train_set = training.filter(ee.Filter.lt('random', 0.7))
val_set = training.filter(ee.Filter.gte('random', 0.7))

# Train the classifier
classifier = ee.Classifier.smileRandomForest(100).train(
    features=train_set,
    classProperty='landcover',
    inputProperties=bands
)

# Evaluate on training data (for comparison)
classified_training = train_set.classify(classifier)
train_conf_matrix = classified_training.errorMatrix('landcover', 'classification')
print('Confusion Matrix (on training data):')
print(train_conf_matrix.getInfo())
print('Training Accuracy:', train_conf_matrix.accuracy().getInfo())

# Evaluate on validation data (more reliable)
val_classified = val_set.classify(classifier)
val_conf_matrix = val_classified.errorMatrix('landcover', 'classification')
print('Validation Confusion Matrix:')
print(val_conf_matrix.getInfo())
print('Validation Accuracy:', val_conf_matrix.accuracy().getInfo())

# Classify the image
classified = composite.select(bands).classify(classifier)

# Visualization parameters for classified map
class_vis = {
    'min': 0,
    'max': 2,
    'palette': ['0000FF', '00FF00', 'FF0000']  # water, vegetation, urban
}

# Add layers to map
Map.addLayer(composite, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 0.3}, 'RGB Composite')
Map.addLayer(classified, class_vis, 'Land Cover Classification')
Map.addLayer(aoi, {}, 'Area of Interest', False)
Map.addLayerControl()

# Add visualization for export - this makes exporting the classification easier
# Fix: classified is a single-band image, so we need to specify bands correctly
visualization_params = {
    'min': 0,
    'max': 2,
    'palette': ['0000FF', '00FF00', 'FF0000']  # water, vegetation, urban
}
Map.addLayer(classified.visualize(**visualization_params), {}, 'Classification for Export')

# Function to overlay classification results on base map
def overlay_classification(base_map_path, classification_path, output_path=None, alpha=0.5):
    """
    Overlay classification results on a base map with transparency
    
    Parameters:
    ----------
    base_map_path : str
        Path to the base map image (e.g., satellite imagery, OpenStreetMap screenshot)
    classification_path : str
        Path to the classification result image
    output_path : str, optional
        Path to save the blended result. If None, will only display
    alpha : float, optional
        Transparency level for the classification overlay (0-1)
    """
    # Load the base map and classified overlay
    base_map = cv2.imread(base_map_path)
    overlay = cv2.imread(classification_path)
    
    if base_map is None or overlay is None:
        raise ValueError("Could not load one or both of the input images")
    
    # Resize if necessary to match dimensions
    overlay = cv2.resize(overlay, (base_map.shape[1], base_map.shape[0]))
    
    # Convert BGR to RGB for plotting
    base_map_rgb = cv2.cvtColor(base_map, cv2.COLOR_BGR2RGB)
    overlay_rgb = cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB)
    
    # Blend overlay with base map
    blended = cv2.addWeighted(overlay_rgb, alpha, base_map_rgb, 1 - alpha, 0)
    
    # Create figure for visualization
    plt.figure(figsize=(12, 10))
    plt.imshow(blended)
    plt.axis('off')
    
    # Add legend
    legend_patches = [
        mpatches.Patch(color='blue', label='Urban'),
        mpatches.Patch(color='green', label='water'),
        mpatches.Patch(color='red', label='Vegetation')
    ]
    plt.legend(handles=legend_patches, loc='lower right', fontsize='large')
    plt.title("Land Cover Classification Overlay")
    
    # Save result if output path is provided
    if output_path:
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        print(f"Blended visualization saved to: {output_path}")
    
    plt.show()

# Export instructions
print("\nTo create a blended visualization:")
print("1. Click on the 'Layers' button in the map")
print("2. Toggle visibility to show only 'RGB Composite' and 'Classification for Export'")
print("3. Use the 'Camera' icon to take screenshots of each layer separately")
print("4. Run the following code to blend the layers (modify paths as needed):")
print("\nbase_map_path = '/path/to/rgb_composite_screenshot.png'")
print("classification_path = '/path/to/classification_screenshot.png'")
print("output_path = '/path/to/save/blended_result.png'  # Optional")
print("overlay_classification(base_map_path, classification_path, output_path, alpha=0.5)")

# Add visualization of training areas to help identify potential issues
print("\nNOTE: Your validation accuracy is 95.6%, but there's confusion between urban and water classes.")
print("To improve classification, visualize and check your training areas:")

# Style the training areas for visualization
water_style = {'color': '0000FF', 'fillColor': '0000FF80'}  # Blue with transparency
vegetation_style = {'color': '00FF00', 'fillColor': '00FF0080'}  # Green with transparency
urban_style = {'color': 'FF0000', 'fillColor': 'FF000080'}  # Red with transparency

# Add training areas to map for verification
Map.addLayer(water.style(**water_style), {}, 'Water Training Areas')
Map.addLayer(vegetation.style(**vegetation_style), {}, 'Vegetation Training Areas')
Map.addLayer(urban.style(**urban_style), {}, 'Urban Training Areas')

print("\nClassification Quality Tips:")
print("1. Check if training areas accurately represent each class (now visible on map)")
print("2. Consider adding more training samples in areas of confusion")
print("3. Industrial areas near water might be misclassified - add specific training samples there")
print("4. Try adjusting the class colors in visualization if they don't match expectations:")
print("   class_vis = {'min': 0, 'max': 2, 'palette': ['YOUR_WATER_COLOR', 'YOUR_VEG_COLOR', 'YOUR_URBAN_COLOR']}")

# Display the map
Map


# Save the map as an HTML file
Map.save('land_cover_classification_map.html')
# Provide instructions for downloading the HTML file    
print("Map saved as 'land_cover_classification_map.html'.")
print("You can download it from the current working directory.")
# Provide instructions for downloading the HTML file
print("You can download it from the current working directory.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Confusion Matrix (on training data):
# [[80, 0, 0], [0, 84, 0], [0, 0, 109]]
# Training Accuracy: 1
# Validation Confusion Matrix:
# [[41, 0, 0], [0, 37, 0], [5, 0, 30]]
# Validation Accuracy: 0.9557522123893806
#
# To create a blended visualization:
# 1. Click on the 'Layers' button in the map
# 2. Toggle visibility to show only 'RGB Composite' and 'Classification for Export'
# 3. Use the 'Camera' icon to take screenshots of each layer separately
# 4. Run the following code to blend the layers (modify paths as needed):
#
# base_map_path = '/path/to/rgb_composite_screenshot.png'
# classification_path = '/path/to/classification_screenshot.png'
# output_path = '/path/to/save/blended_result.png'  # Optional
# overlay_classification(base_map_path, classification_path, output_path, alpha=0.5)
#
# NOTE: Your validation accuracy is 95.6%, but there's confusion between urban and water classes.
# To improve classification, visualize and check your training areas:
#
# Classification Quality Tips:
# 1. Check if training areas accurately represent each class (now visible on map)
# 2. Consider adding more training samples in areas of confusion
# 3. Industrial areas near water might be misclassified - add specific training samples there
# 4. Try adjusting the class colors in visualization if they don't match expectations:
#    class_vis = {'min': 0, 'max': 2, 'palette': ['YOUR_WATER_COLOR', 'YOUR_VEG_COLOR', 'YOUR_URBAN_COLOR']}
# Map saved as 'land_cover_classification_map.html'.
# You can download it from the current working directory.
# You can download it from the current working directory.
